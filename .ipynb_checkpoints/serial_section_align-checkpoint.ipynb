# %%
#handle imports
from serial_section_processing import *

# %% [markdown]
# ## Inputs to use

# %%
#list of files in correct order
src = ['/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-1.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-2.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-3 - 2018-07-18 18.04.40.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-4 - 2018-07-18 04.14.19.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-5 - 2018-07-18 02.10.10.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-6 - 2018-07-17 23.50.06.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-7 - 2018-07-17 21.25.57.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-8 - 2018-07-17 19.05.58.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-9_2 - 2018-07-17 17.18.45.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-10.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-11.ndpis',
       '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-12 - 2018-07-18 19.53.50.ndpis']

#location to save data
dst = '/home/wanglab/LightSheetData/witten-mouse/nanozoomer/output'

#elastix parameter file to use for alignment
parameters = ['/home/wanglab/LightSheetData/witten-mouse/nanozoomer/align_slices_elastix_parameters.txt']

#sectioning depth
section_depth = 40 #um

#nanozoomer level of resolution to use; 1 = full resolution - typically this is too large for most things including fiji, 6 = pretty small
level = 6

#channel to use for alignment e.g. 'Trtc', 'Brighfield'
channel= 'Trtc'

# %% [markdown]
# ### Run

# %%
preprocess(src, dst, parameters = parameters, level = level, channel=channel, verbose=True)
# Out:
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-11-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-1-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-4 - 2018-07-18 04.14.19-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-10-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-5 - 2018-07-18 02.10.10-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-2-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-7 - 2018-07-17 21.25.57-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-6 - 2018-07-17 23.50.06-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-9_2 - 2018-07-17 17.18.45-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-3 - 2018-07-18 18.04.40-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-12 - 2018-07-18 19.53.50-Trtc.ndpi
# Completed /home/wanglab/LightSheetData/witten-mouse/nanozoomer/Rabies/M9332_Rabies_2-8 - 2018-07-17 19.05.58-Trtc.ndpi
# Collecting sections, this can take some time...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-603cfdf34f05> in <module>()
# ----> 1 preprocess(src, dst, parameters = parameters, level = level, channel=channel, verbose=True)
#
# /home/wanglab/wang/pisano/Python/pylign/serial_section_processing.py in preprocess(src, dst, parameters, level, channel, verbose)
#     400
#     401     #now load and collect sections and save them out
# --> 402     find_pixels_from_contours(pnts_dst, dst0, df)
#     403
#     404     #now register
#
# /home/wanglab/wang/pisano/Python/pylign/serial_section_processing.py in find_pixels_from_contours(pnts_dst, dst0, df, verbose)
#     161     '''
#     162     sys.stdout.write('Collecting sections, this can take some time...'); sys.stdout.flush()
# --> 163     dct ={os.path.basename(fl).split('_user_defined')[0].split(channel)[0][:-1]:load_dictionary(fl) for fl in listdirfull(pnts_dst, keyword='.p')}
#     164     for basename, ndct in dct.iteritems():
#     165         tdf = df[df.basename == basename]
#
# /home/wanglab/wang/pisano/Python/pylign/serial_section_processing.py in <dictcomp>((fl,))
#     161     '''
#     162     sys.stdout.write('Collecting sections, this can take some time...'); sys.stdout.flush()
# --> 163     dct ={os.path.basename(fl).split('_user_defined')[0].split(channel)[0][:-1]:load_dictionary(fl) for fl in listdirfull(pnts_dst, keyword='.p')}
#     164     for basename, ndct in dct.iteritems():
#     165         tdf = df[df.basename == basename]
#
# NameError: global name 'channel' is not defined
